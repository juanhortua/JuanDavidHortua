# %%
from opermat import *

def asteriscos():
        print "\n\n", "* " * 4


def verificar_T(T):
        if T is None:
            return "No Esta Definida"
        else:
            return T

A = np.array([[4,7],[1,2],[5,6]])
B = np.array([[4,3,7],[1,2,7],[1,0,4]])
C = np.array([[3],[6],[1]])
D = np.array([[9,4,3,-6],[2,-1,7,5]])
E = np.array([[1,5,8],[7,2,3],[4,0,6]])
F = np.array([[3,0,1],[1,7,3]])
G = np.array([[7,6,4]])

print  " MATRICES "
print "-Matriz A:"
print A
print "\n-Matriz B:"
print B
print "\n-Matriz C:"
print C
print "\n-Matriz D:"
print D
print "\n-Matriz E:"
print E
print "\n-Matriz F:"
print F
print "\n-Matriz G:"
print G
print "\n#", "-" * 92, "#\n"

print " Dimensiones de las Matrices "
print "-Matriz A: ", A.shape[0], " x ", A.shape[1]
print A
print "\n-Matriz B: ", B.shape[0], " x ", B.shape[1]
print B
print "\n-Matriz C: ", C.shape[0], " x ", C.shape[1]
print C
print "\n-Matriz D: ", D.shape[0], " x ", D.shape[1]
print D
print "\n-Matriz E: ", E.shape[0], " x ", E.shape[1]
print E
print "\n-Matriz F: ", F.shape[0], " x ", F.shape[1]
print F
print "\n-Matriz G: ", G.shape[0], " x ", G.shape[1] 
print G
print "\n#", "-" * 92, "#\n"

print " Matriz Cuadrada, Columna y Renglón "
print "Matriz CUADRADA:"
print "Matriz B:"
print B
print "\nMatriz E:"
print E
print "\nMatriz COLUMNA:"
print "Matriz C:"
print C
print "\nMatriz RENGLÓN:"
print "Matriz G:"
print G
print "\n#", "-" * 92, "#\n"

print " Valores Elementos a12, b23, d32, e22, f12 y g12 "
print "-Matriz A:"
print A
print "Elemento a12= ", A[1-1,2-1]
print "\n-Matriz B:"
print B
print "Elemento b23= ", B[2-1,3-1]
print "\n-Matriz D:"
print D
print "Elemento d32= No Existe. Sobrepasa limites de la matriz." 
print "\n-Matriz E:"
print E
print "Elemento e22= ", E[2-1,2-1]
print "\n-Matriz F:"
print F
print "Elemento f12= ", F[1-1,2-1]
print "\n-Matriz G:"
print G
print "Elemento g12= ", G[1-1,2-1]
print "\n#", "-" * 92, "#\n"


op = OperMat()
print " Operaciones "
print "1) [E] + [B]:"
print "[E]"
print E
print "\n[B]"
print B
print "\n[E] + [B]="
T = op.suma(E, B)
print verificar_T(T)

asteriscos()
print "2) [A] + [F]:"
print "[A]"
print A
print "\n[F]"
print F
print "\n[A] + [F]= "
T = op.suma(A, F)
print verificar_T(T)

asteriscos()
print "3) [B] - [E]:"
print "[B]"
print B
print "\n[E]"
print E
print "\n[B] - [E]= "
T = op.diferencia(B, E)
print verificar_T(T)

asteriscos()
print "4) 7 x [B]:"
print "[B]"
print B
print "\nEscalar\n7"
print "\n7 x [B]="
print op.producto_c(7, B)

asteriscos()
print "5) [E] x [B]:"
print "[E]"
print E
print "\n[B]"
print B
print "\n[E] x [B]="
T = op.producto(E, B)
print verificar_T(T)

asteriscos()
print "6) {C}^T:"
print "{C}"
print C
print "\n{C}^T="
print op.transpuesta(C)

asteriscos()
print "7) [B] x [A]:"
print "[B]"
print B
print "\n[A]"
print A
print "\n[B] x [A]= "
T = op.producto(B, A)
print verificar_T(T)

asteriscos()
print "8) [D]^T:"
print "[D]"
print D
print "\n[D]^T="
print op.transpuesta(D)

asteriscos()
print "9) [A] x [C]:"
print "[A]"
print A
print "\n[C]"
print C
print "\n[A] x [C]="
T = op.producto(A, C)
print verificar_T(T)

asteriscos()
print "10) [I] x [B]:"
print "[I]"
I = np.identity((B.shape[0]))
print I
print "\n[B]"
print B
print "\n[I] x [B]= "
T = op.producto(I, B)
print verificar_T(T)

asteriscos()
print "11) [E]^T [E]:"
print "[E]^T"
Et = op.transpuesta(E)
print Et
print "\n[E]"
print E
print "\n[E]^T [E]="
T = op.producto(Et, E)
print verificar_T(T)

asteriscos()
print "12) {C}^T {C}:"
print "{C}^T"
Ct = op.transpuesta(C)
print Ct
print "\n{C}"
print C
print "\n{C}^T {C}="
T = op.producto(Ct, C)
print verificar_T(T)
print "\n#", "-" * 92, "#\n"
# Out:
#  MATRICES
# -Matriz A:
# [[4 7]
#  [1 2]
#  [5 6]]
#
# -Matriz B:
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# -Matriz C:
# [[3]
#  [6]
#  [1]]
#
# -Matriz D:
# [[ 9  4  3 -6]
#  [ 2 -1  7  5]]
#
# -Matriz E:
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# -Matriz F:
# [[3 0 1]
#  [1 7 3]]
#
# -Matriz G:
# [[7 6 4]]
#
# # -------------------------------------------------------------------------------------------- #
#
#  Dimensiones de las Matrices
# -Matriz A:  3  x  2
# [[4 7]
#  [1 2]
#  [5 6]]
#
# -Matriz B:  3  x  3
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# -Matriz C:  3  x  1
# [[3]
#  [6]
#  [1]]
#
# -Matriz D:  2  x  4
# [[ 9  4  3 -6]
#  [ 2 -1  7  5]]
#
# -Matriz E:  3  x  3
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# -Matriz F:  2  x  3
# [[3 0 1]
#  [1 7 3]]
#
# -Matriz G:  1  x  3
# [[7 6 4]]
#
# # -------------------------------------------------------------------------------------------- #
#
#  Matriz Cuadrada, Columna y Renglón
# Matriz CUADRADA:
# Matriz B:
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# Matriz E:
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# Matriz COLUMNA:
# Matriz C:
# [[3]
#  [6]
#  [1]]
#
# Matriz RENGLÓN:
# Matriz G:
# [[7 6 4]]
#
# # -------------------------------------------------------------------------------------------- #
#
#  Valores Elementos a12, b23, d32, e22, f12 y g12
# -Matriz A:
# [[4 7]
#  [1 2]
#  [5 6]]
# Elemento a12=  7
#
# -Matriz B:
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
# Elemento b23=  7
#
# -Matriz D:
# [[ 9  4  3 -6]
#  [ 2 -1  7  5]]
# Elemento d32= No Existe. Sobrepasa limites de la matriz.
#
# -Matriz E:
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
# Elemento e22=  2
#
# -Matriz F:
# [[3 0 1]
#  [1 7 3]]
# Elemento f12=  0
#
# -Matriz G:
# [[7 6 4]]
# Elemento g12=  6
#
# # -------------------------------------------------------------------------------------------- #
#
#  Operaciones
# 1) [E] + [B]:
# [E]
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# [B]
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# [E] + [B]=
# [[  5.   8.  15.]
#  [  8.   4.  10.]
#  [  5.   0.  10.]]
#
#
# * * * *
# 2) [A] + [F]:
# [A]
# [[4 7]
#  [1 2]
#  [5 6]]
#
# [F]
# [[3 0 1]
#  [1 7 3]]
#
# [A] + [F]=
# No Esta Definida
#
#
# * * * *
# 3) [B] - [E]:
# [B]
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# [E]
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# [B] - [E]=
# [[ 3. -2. -1.]
#  [-6.  0.  4.]
#  [-3.  0. -2.]]
#
#
# * * * *
# 4) 7 x [B]:
# [B]
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# Escalar
# 7
#
# 7 x [B]=
# [[ 28.  21.  49.]
#  [  7.  14.  49.]
#  [  7.   0.  28.]]
#
#
# * * * *
# 5) [E] x [B]:
# [E]
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# [B]
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# [E] x [B]=
# [[ 17.  13.  74.]
#  [ 33.  25.  75.]
#  [ 22.  12.  52.]]
#
#
# * * * *
# 6) {C}^T:
# {C}
# [[3]
#  [6]
#  [1]]
#
# {C}^T=
# [[ 3.  6.  1.]]
#
#
# * * * *
# 7) [B] x [A]:
# [B]
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# [A]
# [[4 7]
#  [1 2]
#  [5 6]]
#
# [B] x [A]=
# [[ 54.  76.]
#  [ 41.  53.]
#  [ 24.  31.]]
#
#
# * * * *
# 8) [D]^T:
# [D]
# [[ 9  4  3 -6]
#  [ 2 -1  7  5]]
#
# [D]^T=
# [[ 9.  2.]
#  [ 4. -1.]
#  [ 3.  7.]
#  [-6.  5.]]
#
#
# * * * *
# 9) [A] x [C]:
# [A]
# [[4 7]
#  [1 2]
#  [5 6]]
#
# [C]
# [[3]
#  [6]
#  [1]]
#
# [A] x [C]=
# No Esta Definida
#
#
# * * * *
# 10) [I] x [B]:
# [I]
# [[ 1.  0.  0.]
#  [ 0.  1.  0.]
#  [ 0.  0.  1.]]
#
# [B]
# [[4 3 7]
#  [1 2 7]
#  [1 0 4]]
#
# [I] x [B]=
# [[ 4.  3.  7.]
#  [ 1.  2.  7.]
#  [ 1.  0.  4.]]
#
#
# * * * *
# 11) [E]^T [E]:
# [E]^T
# [[ 1.  7.  4.]
#  [ 5.  2.  0.]
#  [ 8.  3.  6.]]
#
# [E]
# [[1 5 8]
#  [7 2 3]
#  [4 0 6]]
#
# [E]^T [E]=
# [[  66.   19.   53.]
#  [  19.   29.   46.]
#  [  53.   46.  109.]]
#
#
# * * * *
# 12) {C}^T {C}:
# {C}^T
# [[ 3.  6.  1.]]
#
# {C}
# [[3]
#  [6]
#  [1]]
#
# {C}^T {C}=
# [[ 46.]]
#
# # -------------------------------------------------------------------------------------------- #
